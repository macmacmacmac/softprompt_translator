# %%
import os
os.getcwd()
# Out:
# '/home/pkongsomjit/Projects/softprompt_experiments/src/softprompt_experiments'

# %%
import pandas as pd

df = pd.read_json("/home/pkongsomjit/Projects/softprompt_experiments/master_verbalizations_w_new_soft.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   task_name                     96 non-null     object
#  1   hard_prompt                   96 non-null     object
#  2   instances                     96 non-null     object
#  3   mapper_verbalization          96 non-null     object
#  4   inspect_verbalization         96 non-null     object
#  5   mapper_task_rougeL            96 non-null     float64
#  6   soft_task_rougeL              96 non-null     float64
#  7   control_task_rougeL           96 non-null     float64
#  8   inspect_task_rougeL           96 non-null     float64
#  9   fs_task_rougeL                96 non-null     float64
#  10  mapper_verbalization_rougeL   96 non-null     float64
#  11  inspect_verbalization_rougeL  96 non-null     float64
# ...

# %%
df.sort_values(by='soft2_task_rougeL', ascending=False)[['soft2_task_rougeL', 'task_name', 'hard_prompt','instances']].head()
# Out:
#     soft2_task_rougeL                                          task_name  \
# 7                 1.0      task1153_bard_analogical_reasoning_affordance
# 9                 1.0  task1155_bard_analogical_reasoning_trash_or_tr...
# 14                1.0    task1195_disflqa_disfluent_to_fluent_conversion
# 30                1.0          task1516_imppres_naturallanguageinference
# 88                1.0              task828_copa_commonsense_cause_effect
#
#                                           hard_prompt  \
# 7   Two analogies that signify affordances are giv...
# 9   Two analogies that relate items to whether the...
# 14  Given a disfluent sentence, modify the sentenc...
# 30  In this task, you are given a premise and hypo...
# 88  In this task your given two statements. You mu...
#
#                                             instances
# 7   [{'input': 'ride : horse. drink : ?', 'output'...
# 9   [{'input': 'crumbs : trash. remote : ?', 'outp...
# ...

# %%
df['soft2_task_rougeL'].mean()
# Out:
# np.float64(0.6157087790010417)

# %%
tasks_translator_beat_soft = df[df['mapper_task_rougeL'] > df['soft2_task_rougeL']][['task_name', 'mapper_task_rougeL', 'soft2_task_rougeL']]

# %%
tasks_translator_beat_soft['winning_margin'] = df['mapper_task_rougeL'] - df['soft2_task_rougeL']

# %%
sorted_tasks_translator_beat_soft = tasks_translator_beat_soft.sort_values(by='winning_margin', ascending=False)

# %%
sorted_tasks_translator_beat_soft
# Out:
#                                             task_name  mapper_task_rougeL  \
# 64  task349_squad2.0_answerable_unanswerable_quest...            0.900000
# 48                        task199_mnli_classification            0.700000
# 67                task392_inverse_causal_relationship            0.866667
# 42    task1624_disfl_qa_question_yesno_classification            1.000000
# 24                      task1390_wscfixed_coreference            0.600000
# 5                       task050_multirc_answerability            0.800000
# 29                  task1442_doqa_movies_isanswerable            0.800000
# 84           task677_ollie_sentence_answer_generation            0.386262
# 52         task219_rocstories_title_answer_generation            0.092710
# 26                  task1407_dart_question_generation            0.476581
# 77                 task613_politifact_text_generation            0.032749
# 66                        task391_causal_relationship            0.866667
#
# ...

# %%
sorted_tasks_translator_beat_soft['task_name'].iloc[0]
# Out:
# 'task349_squad2.0_answerable_unanswerable_question_classification'

# %%
df['soft2_task_rougeL'].mean()
# Out:
# np.float64(0.6157087790010417)

# %%
df['fs_task_rougeL'].mean()
# Out:
# np.float64(0.6702665861604168)
